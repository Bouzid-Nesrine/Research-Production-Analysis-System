# %%
import os
import json
import re
from html import unescape

# %%
def list_article_attributes(data):
    """
    Returns a set of all unique attributes present in the articles.
    """
    attributes = set()

    if "articles" in data:
        for article in data["articles"]:
            attributes.update(article.keys())

    return attributes

# %%
import re
from html import unescape

def get_articles_list(data):
    """
    Extract articles list from data whether it's a list or has 'articles' key
    """
    if isinstance(data, list):
        return data
    elif isinstance(data, dict) and "articles" in data:
        return data["articles"]
    else:
        return [data]

def set_articles_list(original_data, articles):
    """
    Set articles list back into the original structure
    """
    if isinstance(original_data, list):
        return articles
    elif isinstance(original_data, dict) and "articles" in original_data:
        original_data["articles"] = articles
        return original_data
    else:
        return articles[0] if articles else None

def remove_retracted_articles(data):
    """
    Remove articles from data if 'is_retracted' is True.
    """
    articles = get_articles_list(data)

    # Keep only articles where is_retracted is False or missing
    filtered_articles = [
        article for article in articles
        if not article.get("is_retracted", False)
    ]

    return set_articles_list(data, filtered_articles)

def remove_unwanted_attributes(data):
    """
    Remove specified attributes from each article in the JSON data.
    """
    unwanted_attrs = [
        'id', 'doi', 'ids', 'publication_year', 'institution_assertions',
        'corresponding_author_ids', 'is_corresponding', 'corresponding_institution_ids',
        'apc_list', 'apc_paid', 'has_fulltext', 'biblio', 'fulltext_origin',
        'is_paratext', 'concepts', 'locations_count', 'locations', 'best_oa_location',
        'sustainable_development_goals', 'grants', 'datasets', 'versions',
        'referenced_works_count', 'referenced_works', 'related_works',
        'cited_by_api_url', 'counts_by_year', 'updated_date', 'created_date',
        'type', 'type_crossref', 'indexed_in', 'open_access', 'mesh'
    ]

    articles = get_articles_list(data)

    for article in articles:
        for attr in unwanted_attrs:
            if attr in article:
                del article[attr]

    return set_articles_list(data, articles)

def handle_missing_fields(data, placeholder="N/A"):
    """
    Check important text fields in each article.
    If a field is missing or empty, fill it with a placeholder.
    """
    fields_to_check = ["title", "abstract"]

    articles = get_articles_list(data)

    for article in articles:
        for field in fields_to_check:
            if field not in article or not article[field] or article[field].strip() == "":
                article[field] = placeholder

    return set_articles_list(data, articles)

def normalize_text(data):
    """
    Normalize text fields ('title' and 'abstract') in each article:
    - Lowercase
    - Remove extra spaces and line breaks
    - Remove HTML tags and special characters
    """
    def clean_text(text):
        if not text:
            return ""
        # Decode HTML entities
        text = unescape(text)
        # Remove HTML tags
        text = re.sub(r"<.*?>", " ", text)
        # Remove non-printable or weird characters
        text = re.sub(r"[^ -~\n]", " ", text)
        # Replace multiple spaces or newlines with a single space
        text = re.sub(r"\s+", " ", text)
        # Strip leading/trailing spaces
        return text.strip().lower()

    articles = get_articles_list(data)

    for article in articles:
        if "title" in article:
            article["title"] = clean_text(article["title"])
        if "abstract" in article:
            article["abstract"] = clean_text(article["abstract"])

    return set_articles_list(data, articles)

def handle_abstract(data):
    """
    Reconstruct the abstract from 'abstract_inverted_index' for each article.
    Replaces 'abstract_inverted_index' with 'abstract'.
    """
    articles = get_articles_list(data)

    for article in articles:
        inverted_index = article.get("abstract_inverted_index")

        if inverted_index:
            # Create a dict with position as key and word as value
            position_word = {}
            for word, positions in inverted_index.items():
                for pos in positions:
                    position_word[pos] = word

            # Reconstruct abstract based on sorted positions
            abstract_words = [position_word[pos] for pos in sorted(position_word.keys())]
            article["abstract"] = " ".join(abstract_words)

        # Remove the original inverted index in any case
        if "abstract_inverted_index" in article:
            del article["abstract_inverted_index"]

    return set_articles_list(data, articles)

def handle_primary_location(data):
    """
    Simplify the 'primary_location' field into 'publication_info'.
    """
    articles = get_articles_list(data)

    for article in articles:
        primary = article.get("primary_location")
        if primary is not None:
            source = primary.get("source")
            if source is not None:
                article["publication_info"] = {
                    "host_organization_name": source.get("host_organization_name"),
                    "host_organization_lineage_names": source.get("host_organization_lineage_names"),
                    "type": source.get("type")
                }
            else:
                article["publication_info"] = {
                    "host_organization_name": None,
                    "host_organization_lineage_names": None,
                    "type": None
                }
            del article["primary_location"]

    return set_articles_list(data, articles)

def handle_authorships(data):
    """
    Simplify the 'authorships' field for each article.
    Keeps only: author name, author position, institutions, countries, and is_corresponding.
    """
    articles = get_articles_list(data)

    for article in articles:
        if "authorships" in article:
            simplified_authors = []
            for auth in article["authorships"]:
                author_name = auth.get("author", {}).get("display_name")
                author_position = auth.get("author_position")
                institutions = [
                    inst.get("display_name") if isinstance(inst, dict) else inst
                    for inst in auth.get("institutions", [])
                ]
                countries = auth.get("countries", [])
                is_corresponding = auth.get("is_corresponding", False)

                simplified_authors.append({
                    "name": author_name,
                    "position": author_position,
                    "institutions": institutions,
                    "countries": countries,
                    "is_corresponding": is_corresponding
                })

            article["authorships"] = simplified_authors

    return set_articles_list(data, articles)

def handle_topics(data, max_topics=3):
    """
    Simplify primary_topic and topics for each article.
    Keeps only human-readable display names.
    """
    articles = get_articles_list(data)

    for article in articles:
        # Handle primary_topic
        primary = article.get("primary_topic")
        if primary:
            article["primary_topic_name"] = primary.get("display_name")
            del article["primary_topic"]

        # Handle topics list
        topics_list = article.get("topics", [])
        if topics_list:
            article["topics_names"] = [t.get("display_name") for t in topics_list[:max_topics]]
            del article["topics"]

    return set_articles_list(data, articles)

def handle_keywords(data, max_keywords=10):
    """
    Simplify 'keywords' for each article.
    Keeps only the top N keyword display names.
    """
    articles = get_articles_list(data)

    for article in articles:
        keywords_list = article.get("keywords", [])
        if keywords_list:
            article["keywords_names"] = [k.get("display_name") for k in keywords_list[:max_keywords]]
            del article["keywords"]

    return set_articles_list(data, articles)

def build_classification_path(article):
    """
    Build classification path from domain -> field -> subfield -> topic.
    """
    classification_path = []

    # Try both possible field names since handle_topics renames primary_topic
    if 'primary_topic' in article and article['primary_topic']:
        primary_topic = article['primary_topic']
    elif 'primary_topic_name' in article and article['primary_topic_name']:
        # If handle_topics already ran, we only have the name
        return [article['primary_topic_name']]  # Simplified path
    else:
        return []

    if primary_topic:
        classification_path.extend([
            primary_topic['domain']['display_name'],
            primary_topic['field']['display_name'],
            primary_topic['subfield']['display_name'],
            primary_topic['display_name']
        ])

    return classification_path

def handle_classification_path(data):
    """
    Add a 'classification_path' field to each article using build_classification_path().
    """
    articles = get_articles_list(data)

    for article in articles:
        article["classification_path"] = build_classification_path(article)

    return set_articles_list(data, articles)

def remove_incomplete_articles(data):
    """
    Remove articles with missing or empty:
    - title
    - abstract
    - authorships (must have at least one)
    Also removes articles where these fields are completely absent.
    """
    articles = get_articles_list(data)

    cleaned_articles = []
    for article in articles:
        title = article.get("title")
        abstract = article.get("abstract")
        authorships = article.get("authorships", [])
        citations = article.get("cited_by_count", None)

        # Check if title is missing or empty
        if not title or not str(title).strip():
            continue
        # Check if abstract is missing or empty
        if not abstract or not str(abstract).strip():
            continue
        # Check if authorships is missing or empty
        if not isinstance(authorships, list) or len(authorships) == 0:
            continue
        # Only remove if citations is completely missing (None), not if it's 0
        if citations is None:
            continue

        cleaned_articles.append(article)

    print(f" Kept {len(cleaned_articles)} / {len(articles)} valid articles.")
    return set_articles_list(data, cleaned_articles)

# %%
import json
import os

# Add more functions as needed
preprocessing_functions = [
    remove_retracted_articles,
    remove_unwanted_attributes,
    handle_abstract,
    handle_primary_location,
    handle_classification_path,
    handle_authorships,
    handle_topics,
    handle_keywords,
    handle_missing_fields,
    normalize_text,
    remove_incomplete_articles
]

# Source folder (raw data)
input_folder = "/content/drive/MyDrive/Data Collection /Rayane"

# Output folder (processed data)
output_folder = "/content/drive/MyDrive/Rayane_Preprocessing"

# Create output folder if it doesn't exist
os.makedirs(output_folder, exist_ok=True)

# Loop through files in the input folder
for filename in os.listdir(input_folder):
    if filename.endswith(".json"):
        input_file_path = os.path.join(input_folder, filename)
        output_file_path = os.path.join(output_folder, filename)

        print(f"Processing {filename}...")

        try:
            # Read JSON data
            with open(input_file_path, "r", encoding="utf-8") as f:
                data = json.load(f)

            # Apply preprocessing functions
            for func in preprocessing_functions:
                data = func(data)

            # Save processed data to the new folder
            with open(output_file_path, "w", encoding="utf-8") as f:
                json.dump(data, f, ensure_ascii=False, indent=4)

            print(f" ✔ Successfully processed and saved: {filename}")

        except Exception as e:
            print(f" ❌ Error processing {filename}: {str(e)}")
            continue

print("🎉 All files processed and saved to the new folder!")
# Out:
# Processing Public-Private Partnership Projects.json...
#  Kept 4982 / 4999 valid articles.
#  ✔ Successfully processed and saved: Public-Private Partnership Projects.json
# Processing Capital Investment and Risk Analysis.json...
#  Kept 4987 / 4997 valid articles.
#  ✔ Successfully processed and saved: Capital Investment and Risk Analysis.json
# Processing World Wars_ History, Literature, and Impact.json...
#  Kept 4978 / 5000 valid articles.
#  ✔ Successfully processed and saved: World Wars_ History, Literature, and Impact.json
# Processing Participatory Visual Research Methods.json...
#  Kept 4988 / 4999 valid articles.
#  ✔ Successfully processed and saved: Participatory Visual Research Methods.json
# Processing Qualitative Research Methods and Ethics.json...
#  Kept 4987 / 5000 valid articles.
#  ✔ Successfully processed and saved: Qualitative Research Methods and Ethics.json
# Processing Technology Use by Older Adults.json...
#  Kept 4968 / 5000 valid articles.
#  ✔ Successfully processed and saved: Technology Use by Older Adults.json
# Processing Human Mobility and Location-Based Analysis.json...
#  Kept 4992 / 4998 valid articles.
#  ✔ Successfully processed and saved: Human Mobility and Location-Based Analysis.json
# Processing FinTech, Crowdfunding, Digital Finance.json...
#  Kept 2206 / 2256 valid articles.
#  ✔ Successfully processed and saved: FinTech, Crowdfunding, Digital Finance.json
# Processing Rhetoric and Communication Studies.json...
#  Kept 4989 / 4999 valid articles.
#  ✔ Successfully processed and saved: Rhetoric and Communication Studies.json
# Processing Identity, Memory, and Therapy.json...
#  Kept 4982 / 4998 valid articles.
#  ✔ Successfully processed and saved: Identity, Memory, and Therapy.json
# Processing Human Resource Development and Performance Evaluation.json...
#  Kept 4969 / 4998 valid articles.
#  ✔ Successfully processed and saved: Human Resource Development and Performance Evaluation.json
# Processing Ergonomics and Musculoskeletal Disorders.json...
#  Kept 4949 / 4999 valid articles.
#  ✔ Successfully processed and saved: Ergonomics and Musculoskeletal Disorders.json
# Processing Youth Development and Social Support.json...
#  Kept 4968 / 4999 valid articles.
#  ✔ Successfully processed and saved: Youth Development and Social Support.json
# Processing Insurance, Mortality, Demography, Risk Management.json...
#  Kept 4970 / 4999 valid articles.
#  ✔ Successfully processed and saved: Insurance, Mortality, Demography, Risk Management.json
# Processing Social and Educational Sciences.json...
#  Kept 4970 / 4999 valid articles.
#  ✔ Successfully processed and saved: Social and Educational Sciences.json
# Processing Social Media in Health Education.json...
#  Kept 4962 / 4999 valid articles.
#  ✔ Successfully processed and saved: Social Media in Health Education.json
# Processing Knowledge Management and Sharing.json...
#  Kept 4976 / 4994 valid articles.
#  ✔ Successfully processed and saved: Knowledge Management and Sharing.json
# Processing Multisensory perception and integration.json...
#  Kept 4998 / 4999 valid articles.
#  ✔ Successfully processed and saved: Multisensory perception and integration.json
# Processing International Arbitration and Investment Law.json...
#  Kept 4914 / 5000 valid articles.
#  ✔ Successfully processed and saved: International Arbitration and Investment Law.json
# Processing Diversity and Impact of Dance.json...
#  Kept 4985 / 4999 valid articles.
#  ✔ Successfully processed and saved: Diversity and Impact of Dance.json
# Processing Polish socio-economic development.json...
#  Kept 4986 / 5000 valid articles.
#  ✔ Successfully processed and saved: Polish socio-economic development.json
# Processing Child Development and Digital Technology.json...
#  Kept 4982 / 5000 valid articles.
#  ✔ Successfully processed and saved: Child Development and Digital Technology.json
# Processing Writing and Handwriting Education.json...
#  Kept 4991 / 4999 valid articles.
#  ✔ Successfully processed and saved: Writing and Handwriting Education.json
# Processing Renaissance and Early Modern Studies.json...
#  Kept 4950 / 5000 valid articles.
#  ✔ Successfully processed and saved: Renaissance and Early Modern Studies.json
# Processing Karst Systems and Hydrogeology.json...
#  Kept 4001 / 4231 valid articles.
#  ✔ Successfully processed and saved: Karst Systems and Hydrogeology.json
# Processing Intergenerational and Educational Inequality Studies.json...
#  Kept 4997 / 5000 valid articles.
#  ✔ Successfully processed and saved: Intergenerational and Educational Inequality Studies.json
# Processing Language and cultural evolution.json...
#  Kept 4979 / 5000 valid articles.
#  ✔ Successfully processed and saved: Language and cultural evolution.json
# Processing Race, Identity, and Education in Brazil.json...
#  Kept 4968 / 4999 valid articles.
#  ✔ Successfully processed and saved: Race, Identity, and Education in Brazil.json
# Processing Linguistics and Discourse Analysis.json...
#  Kept 4971 / 4997 valid articles.
#  ✔ Successfully processed and saved: Linguistics and Discourse Analysis.json
# Processing Cooperative Studies and Economics.json...
#  Kept 4977 / 4999 valid articles.
#  ✔ Successfully processed and saved: Cooperative Studies and Economics.json
# Processing Financial Analysis and Corporate Governance.json...
#  Kept 4982 / 4997 valid articles.
#  ✔ Successfully processed and saved: Financial Analysis and Corporate Governance.json
# Processing Contemporary Literature and Criticism.json...
#  Kept 4969 / 5000 valid articles.
#  ✔ Successfully processed and saved: Contemporary Literature and Criticism.json
# Processing Pragmatism in Philosophy and Education.json...
#  Kept 4982 / 5000 valid articles.
#  ✔ Successfully processed and saved: Pragmatism in Philosophy and Education.json
# Processing Economic theories and models.json...
#  Kept 4977 / 4998 valid articles.
#  ✔ Successfully processed and saved: Economic theories and models.json
# Processing Place Attachment and Urban Studies.json...
#  Kept 4990 / 4999 valid articles.
#  ✔ Successfully processed and saved: Place Attachment and Urban Studies.json
# Processing Marine Invertebrate Physiology and Ecology.json...
#  Kept 4989 / 4999 valid articles.
#  ✔ Successfully processed and saved: Marine Invertebrate Physiology and Ecology.json
# Processing Colonialism, slavery, and trade.json...
#  Kept 4963 / 4999 valid articles.
#  ✔ Successfully processed and saved: Colonialism, slavery, and trade.json
# Processing Urban and Rural Development Challenges.json...
#  Kept 4976 / 5000 valid articles.
#  ✔ Successfully processed and saved: Urban and Rural Development Challenges.json
# Processing World Trade Organization Law.json...
#  Kept 4959 / 4997 valid articles.
#  ✔ Successfully processed and saved: World Trade Organization Law.json
# Processing Education Practices and Challenges.json...
#  Kept 4986 / 5000 valid articles.
#  ✔ Successfully processed and saved: Education Practices and Challenges.json
# Processing Social Representations and Identity.json...
#  Kept 4975 / 4999 valid articles.
#  ✔ Successfully processed and saved: Social Representations and Identity.json
# Processing Linguistics and Education Research.json...
#  Kept 4969 / 4997 valid articles.
#  ✔ Successfully processed and saved: Linguistics and Education Research.json
# Processing Evolution and Science Education.json...
#  Kept 4962 / 4999 valid articles.
#  ✔ Successfully processed and saved: Evolution and Science Education.json
# Processing Regulation and Compliance Studies.json...
#  Kept 4986 / 5000 valid articles.
#  ✔ Successfully processed and saved: Regulation and Compliance Studies.json
# Processing Cultural Competency in Health Care.json...
#  Kept 4949 / 4999 valid articles.
#  ✔ Successfully processed and saved: Cultural Competency in Health Care.json
# Processing nanoparticles nucleation surface interactions.json...
#  Kept 4996 / 4999 valid articles.
#  ✔ Successfully processed and saved: nanoparticles nucleation surface interactions.json
# Processing Policy Transfer and Learning.json...
#  Kept 4985 / 4998 valid articles.
#  ✔ Successfully processed and saved: Policy Transfer and Learning.json
# Processing Media Influence and Health.json...
#  Kept 4971 / 4996 valid articles.
#  ✔ Successfully processed and saved: Media Influence and Health.json
# Processing Higher Education Teaching and Evaluation.json...
#  Kept 4957 / 4971 valid articles.
#  ✔ Successfully processed and saved: Higher Education Teaching and Evaluation.json
# Processing Coal and Its By-products.json...
#  Kept 4946 / 4997 valid articles.
#  ✔ Successfully processed and saved: Coal and Its By-products.json
# Processing Cybersecurity and Cyber Warfare Studies.json...
#  Kept 2260 / 2315 valid articles.
#  ✔ Successfully processed and saved: Cybersecurity and Cyber Warfare Studies.json
# Processing Canadian Identity and History.json...
#  Kept 4979 / 5000 valid articles.
#  ✔ Successfully processed and saved: Canadian Identity and History.json
# Processing Political Influence and Corporate Strategies.json...
#  Kept 4993 / 5000 valid articles.
#  ✔ Successfully processed and saved: Political Influence and Corporate Strategies.json
# Processing Contemporary Sociological Theory and Practice.json...
#  Kept 4984 / 5000 valid articles.
#  ✔ Successfully processed and saved: Contemporary Sociological Theory and Practice.json
# Processing Latin American and Latino Studies.json...
#  Kept 4979 / 5000 valid articles.
#  ✔ Successfully processed and saved: Latin American and Latino Studies.json
# Processing Counseling, Therapy, and Family Dynamics.json...
#  Kept 4950 / 4998 valid articles.
#  ✔ Successfully processed and saved: Counseling, Therapy, and Family Dynamics.json
# Processing Children's Physical and Motor Development.json...
#  Kept 4979 / 4999 valid articles.
#  ✔ Successfully processed and saved: Children's Physical and Motor Development.json
# Processing Perfectionism, Procrastination, Anxiety Studies.json...
#  Kept 1858 / 1887 valid articles.
#  ✔ Successfully processed and saved: Perfectionism, Procrastination, Anxiety Studies.json
# Processing Water Governance and Infrastructure.json...
#  Kept 4983 / 5000 valid articles.
#  ✔ Successfully processed and saved: Water Governance and Infrastructure.json
# Processing Facilities and Workplace Management.json...
#  Kept 4969 / 4998 valid articles.
#  ✔ Successfully processed and saved: Facilities and Workplace Management.json
# Processing Environmental Justice and Health Disparities.json...
#  Kept 4975 / 5000 valid articles.
#  ✔ Successfully processed and saved: Environmental Justice and Health Disparities.json
# Processing Byzantine Studies and History.json...
#  Kept 4976 / 5000 valid articles.
#  ✔ Successfully processed and saved: Byzantine Studies and History.json
# Processing Peacebuilding and International Security.json...
#  Kept 4967 / 4998 valid articles.
#  ✔ Successfully processed and saved: Peacebuilding and International Security.json
# Processing Latin American Urban Studies.json...
#  Kept 4979 / 5000 valid articles.
#  ✔ Successfully processed and saved: Latin American Urban Studies.json
# Processing Emotional Labor in Professions.json...
#  Kept 4989 / 5000 valid articles.
#  ✔ Successfully processed and saved: Emotional Labor in Professions.json
# Processing Latin American history and culture.json...
#  Kept 4956 / 5000 valid articles.
#  ✔ Successfully processed and saved: Latin American history and culture.json
# Processing Risk Management in Financial Firms.json...
#  Kept 4986 / 5000 valid articles.
#  ✔ Successfully processed and saved: Risk Management in Financial Firms.json
# Processing Foucault, Power, and Ethics.json...
#  Kept 4981 / 5000 valid articles.
#  ✔ Successfully processed and saved: Foucault, Power, and Ethics.json
# Processing Library Science and Administration.json...
#  Kept 4949 / 4997 valid articles.
#  ✔ Successfully processed and saved: Library Science and Administration.json
# Processing Mental Health and Psychiatry.json...
#  Kept 4965 / 5000 valid articles.
#  ✔ Successfully processed and saved: Mental Health and Psychiatry.json
# Processing Political Theology and Sovereignty.json...
#  Kept 4980 / 5000 valid articles.
#  ✔ Successfully processed and saved: Political Theology and Sovereignty.json
# Processing Culture, Economy, and Development Studies.json...
#  Kept 4971 / 4992 valid articles.
#  ✔ Successfully processed and saved: Culture, Economy, and Development Studies.json
# Processing Emotions and Moral Behavior.json...
#  Kept 4985 / 4997 valid articles.
#  ✔ Successfully processed and saved: Emotions and Moral Behavior.json
# Processing Comparative constitutional jurisprudence studies.json...
#  Kept 4969 / 5000 valid articles.
#  ✔ Successfully processed and saved: Comparative constitutional jurisprudence studies.json
# Processing History of Medicine Studies.json...
#  Kept 4951 / 4998 valid articles.
#  ✔ Successfully processed and saved: History of Medicine Studies.json
# Processing Italian Fascism and Post-war Society.json...
#  Kept 4985 / 5000 valid articles.
#  ✔ Successfully processed and saved: Italian Fascism and Post-war Society.json
# Processing Spanish Linguistics and Language Studies.json...
#  Kept 4979 / 4999 valid articles.
#  ✔ Successfully processed and saved: Spanish Linguistics and Language Studies.json
# Processing Geography Education and Pedagogy.json...
#  Kept 4985 / 4999 valid articles.
#  ✔ Successfully processed and saved: Geography Education and Pedagogy.json
# Processing Philosophy, Ethics, and Existentialism.json...
#  Kept 3479 / 3650 valid articles.
#  ✔ Successfully processed and saved: Philosophy, Ethics, and Existentialism.json
# Processing Lexicography and Language Studies.json...
#  Kept 4976 / 4999 valid articles.
#  ✔ Successfully processed and saved: Lexicography and Language Studies.json
# Processing Innovations in Educational Methods.json...
#  Kept 4947 / 4979 valid articles.
#  ✔ Successfully processed and saved: Innovations in Educational Methods.json
# Processing Linguistic research and analysis.json...
#  Kept 4991 / 4998 valid articles.
#  ✔ Successfully processed and saved: Linguistic research and analysis.json
# Processing European and International Contract Law.json...
#  Kept 4961 / 5000 valid articles.
#  ✔ Successfully processed and saved: European and International Contract Law.json
# Processing Cuban History and Society.json...
#  Kept 4965 / 5000 valid articles.
#  ✔ Successfully processed and saved: Cuban History and Society.json
# Processing Customer churn and segmentation.json...
#  Kept 2217 / 2274 valid articles.
#  ✔ Successfully processed and saved: Customer churn and segmentation.json
# Processing Digital Humanities and Scholarship.json...
#  Kept 4981 / 4998 valid articles.
#  ✔ Successfully processed and saved: Digital Humanities and Scholarship.json
# Processing Corporate Management and Leadership.json...
#  Kept 4981 / 4997 valid articles.
#  ✔ Successfully processed and saved: Corporate Management and Leadership.json
# Processing History of Education Research in Brazil.json...
#  Kept 4970 / 4999 valid articles.
#  ✔ Successfully processed and saved: History of Education Research in Brazil.json
# Processing Comics and Graphic Narratives.json...
#  Kept 4926 / 5000 valid articles.
#  ✔ Successfully processed and saved: Comics and Graphic Narratives.json
# Processing Workplace Spirituality and Leadership.json...
#  Kept 4957 / 4999 valid articles.
#  ✔ Successfully processed and saved: Workplace Spirituality and Leadership.json
# Processing Sharing Economy and Platforms.json...
#  Kept 4975 / 4996 valid articles.
#  ✔ Successfully processed and saved: Sharing Economy and Platforms.json
# Processing Critical Theory and Philosophy.json...
#  Kept 4963 / 5000 valid articles.
#  ✔ Successfully processed and saved: Critical Theory and Philosophy.json
# Processing Insurance and Financial Risk Management.json...
#  Kept 4957 / 4998 valid articles.
#  ✔ Successfully processed and saved: Insurance and Financial Risk Management.json
# Processing Poetry Analysis and Criticism.json...
#  Kept 4975 / 5000 valid articles.
#  ✔ Successfully processed and saved: Poetry Analysis and Criticism.json
# Processing Employer Branding and e-HRM.json...
#  Kept 1158 / 1181 valid articles.
#  ✔ Successfully processed and saved: Employer Branding and e-HRM.json
# Processing Wine Industry and Tourism.json...
#  Kept 4995 / 5000 valid articles.
#  ✔ Successfully processed and saved: Wine Industry and Tourism.json
# Processing Reformation and Early Modern Christianity.json...
#  Kept 4975 / 4999 valid articles.
#  ✔ Successfully processed and saved: Reformation and Early Modern Christianity.json
# Processing Karl Barth and Christian Theology.json...
#  Kept 4906 / 4999 valid articles.
#  ✔ Successfully processed and saved: Karl Barth and Christian Theology.json
# Processing Earthquake Detection and Analysis.json...
#  Kept 4990 / 4996 valid articles.
#  ✔ Successfully processed and saved: Earthquake Detection and Analysis.json
# Processing Global Trade and Competitiveness.json...
#  Kept 4976 / 4999 valid articles.
#  ✔ Successfully processed and saved: Global Trade and Competitiveness.json
# Processing Delphi Technique in Research.json...
#  Kept 4982 / 4999 valid articles.
#  ✔ Successfully processed and saved: Delphi Technique in Research.json
# Processing Twentieth Century Scientific Developments.json...
#  Kept 4956 / 5000 valid articles.
#  ✔ Successfully processed and saved: Twentieth Century Scientific Developments.json
# Processing Paranormal Experiences and Beliefs.json...
#  Kept 4940 / 4999 valid articles.
#  ✔ Successfully processed and saved: Paranormal Experiences and Beliefs.json
# Processing Economic Growth and Fiscal Policies.json...
#  Kept 4922 / 5000 valid articles.
#  ✔ Successfully processed and saved: Economic Growth and Fiscal Policies.json
# Processing Geotourism and Geoheritage Conservation.json...
#  Kept 979 / 989 valid articles.
#  ✔ Successfully processed and saved: Geotourism and Geoheritage Conservation.json
# Processing European Political History Analysis.json...
#  Kept 4964 / 4999 valid articles.
#  ✔ Successfully processed and saved: European Political History Analysis.json
# Processing Ecocriticism and Environmental Literature.json...
#  Kept 4900 / 4999 valid articles.
#  ✔ Successfully processed and saved: Ecocriticism and Environmental Literature.json
# Processing Narrative Theory and Analysis.json...
#  Kept 4980 / 5000 valid articles.
#  ✔ Successfully processed and saved: Narrative Theory and Analysis.json
# Processing Caribbean and African Literature and Culture.json...
#  Kept 4977 / 5000 valid articles.
#  ✔ Successfully processed and saved: Caribbean and African Literature and Culture.json
# Processing Education Discipline and Inequality.json...
#  Kept 4982 / 4999 valid articles.
#  ✔ Successfully processed and saved: Education Discipline and Inequality.json
# Processing History of Science and Natural History.json...
#  Kept 4957 / 5000 valid articles.
#  ✔ Successfully processed and saved: History of Science and Natural History.json
# Processing Pacific and Southeast Asian Studies.json...
#  Kept 4979 / 4998 valid articles.
#  ✔ Successfully processed and saved: Pacific and Southeast Asian Studies.json
# Processing Wikis in Education and Collaboration.json...
#  Kept 4989 / 5000 valid articles.
#  ✔ Successfully processed and saved: Wikis in Education and Collaboration.json
# Processing Digital Accessibility for Disabilities.json...
#  Kept 4978 / 4998 valid articles.
#  ✔ Successfully processed and saved: Digital Accessibility for Disabilities.json
# Processing Global Urban Networks and Dynamics.json...
#  Kept 4977 / 4999 valid articles.
#  ✔ Successfully processed and saved: Global Urban Networks and Dynamics.json
# Processing Optimism, Hope, and Well-being.json...
#  Kept 4967 / 4999 valid articles.
#  ✔ Successfully processed and saved: Optimism, Hope, and Well-being.json
# Processing Mental Health via Writing.json...
#  Kept 4967 / 4997 valid articles.
#  ✔ Successfully processed and saved: Mental Health via Writing.json
# Processing Color perception and design.json...
#  Kept 4977 / 4997 valid articles.
#  ✔ Successfully processed and saved: Color perception and design.json
# Processing Software Engineering and Design Patterns.json...
#  Kept 4981 / 4999 valid articles.
#  ✔ Successfully processed and saved: Software Engineering and Design Patterns.json
# Processing Latin American Cultural Politics.json...
#  Kept 4967 / 5000 valid articles.
#  ✔ Successfully processed and saved: Latin American Cultural Politics.json
# Processing Reflective Practices in Education.json...
#  Kept 4992 / 4999 valid articles.
#  ✔ Successfully processed and saved: Reflective Practices in Education.json
# Processing Utopian, Dystopian, and Speculative Fiction.json...
#  Kept 1352 / 1378 valid articles.
#  ✔ Successfully processed and saved: Utopian, Dystopian, and Speculative Fiction.json
# Processing Urbanization and City Planning.json...
#  Kept 4981 / 4994 valid articles.
#  ✔ Successfully processed and saved: Urbanization and City Planning.json
# Processing Digital Economy and Work Transformation.json...
#  Kept 4978 / 5000 valid articles.
#  ✔ Successfully processed and saved: Digital Economy and Work Transformation.json
# Processing Social Acceptance of Renewable Energy.json...
#  Kept 4988 / 5000 valid articles.
#  ✔ Successfully processed and saved: Social Acceptance of Renewable Energy.json
# Processing Medieval and Classical Philosophy.json...
#  Kept 4974 / 5000 valid articles.
#  ✔ Successfully processed and saved: Medieval and Classical Philosophy.json
# Processing Corporate Insolvency and Governance.json...
#  Kept 4966 / 4998 valid articles.
#  ✔ Successfully processed and saved: Corporate Insolvency and Governance.json
# Processing History of Colonial Brazil.json...
#  Kept 4979 / 4999 valid articles.
#  ✔ Successfully processed and saved: History of Colonial Brazil.json
# Processing Fashion and Cultural Textiles.json...
#  Kept 4988 / 4999 valid articles.
#  ✔ Successfully processed and saved: Fashion and Cultural Textiles.json
# Processing Seventeenth-Century Political and Philosophical Thought.json...
#  Kept 4963 / 5000 valid articles.
#  ✔ Successfully processed and saved: Seventeenth-Century Political and Philosophical Thought.json
# Processing Values and Moral Education.json...
#  Kept 4965 / 4993 valid articles.
#  ✔ Successfully processed and saved: Values and Moral Education.json
# Processing Death Anxiety and Social Exclusion.json...
#  Kept 4980 / 4999 valid articles.
#  ✔ Successfully processed and saved: Death Anxiety and Social Exclusion.json
# Processing Historical and Cultural Archaeology Studies.json...
#  Kept 4984 / 4999 valid articles.
#  ✔ Successfully processed and saved: Historical and Cultural Archaeology Studies.json
# Processing Second Language Learning and Teaching.json...
#  Kept 4982 / 4999 valid articles.
#  ✔ Successfully processed and saved: Second Language Learning and Teaching.json
# Processing Global Education and Multiculturalism.json...
#  Kept 4979 / 5000 valid articles.
#  ✔ Successfully processed and saved: Global Education and Multiculturalism.json
# Processing Working Capital and Financial Performance.json...
#  Kept 4978 / 5000 valid articles.
#  ✔ Successfully processed and saved: Working Capital and Financial Performance.json
# Processing Politics and Conflicts in Afghanistan, Pakistan, and Middle East.json...
#  Kept 4975 / 5000 valid articles.
#  ✔ Successfully processed and saved: Politics and Conflicts in Afghanistan, Pakistan, and Middle East.json
# Processing Forgiveness and Related Behaviors.json...
#  Kept 4985 / 4999 valid articles.
#  ✔ Successfully processed and saved: Forgiveness and Related Behaviors.json
# Processing Wittgensteinian philosophy and applications.json...
#  ❌ Error processing Wittgensteinian philosophy and applications.json: Expecting ',' delimiter: line 998631 column 13 (char 23413677)
# Processing Hospitality and Tourism Education.json...
#  Kept 4964 / 4991 valid articles.
#  ✔ Successfully processed and saved: Hospitality and Tourism Education.json
# Processing Education and Digital Technologies.json...
#  Kept 4959 / 4990 valid articles.
#  ✔ Successfully processed and saved: Education and Digital Technologies.json
# Processing French Literature and Critical Theory.json...
#  Kept 4979 / 5000 valid articles.
#  ✔ Successfully processed and saved: French Literature and Critical Theory.json
# Processing History and Politics in Latin America.json...
#  Kept 4945 / 5000 valid articles.
#  ✔ Successfully processed and saved: History and Politics in Latin America.json
# Processing Intelligence, Security, War Strategy.json...
#  Kept 4978 / 5000 valid articles.
#  ✔ Successfully processed and saved: Intelligence, Security, War Strategy.json
# Processing Educational Methods and Analysis.json...
#  Kept 4990 / 4998 valid articles.
#  ✔ Successfully processed and saved: Educational Methods and Analysis.json
# Processing Medical History and Research.json...
#  Kept 4953 / 4997 valid articles.
#  ✔ Successfully processed and saved: Medical History and Research.json
# Processing North African History and Literature.json...
#  Kept 4982 / 4999 valid articles.
#  ✔ Successfully processed and saved: North African History and Literature.json
# Processing Folklore, Mythology, and Literature Studies.json...
#  Kept 4957 / 5000 valid articles.
#  ✔ Successfully processed and saved: Folklore, Mythology, and Literature Studies.json
# Processing STEM Education.json...
#  Kept 4974 / 4996 valid articles.
#  ✔ Successfully processed and saved: STEM Education.json
# Processing Inclusive Education and Diversity.json...
#  Kept 4975 / 5000 valid articles.
#  ✔ Successfully processed and saved: Inclusive Education and Diversity.json
# Processing Collaboration in agile enterprises.json...
#  Kept 4990 / 4995 valid articles.
#  ✔ Successfully processed and saved: Collaboration in agile enterprises.json
# Processing Latin American socio-political dynamics.json...
#  Kept 4971 / 5000 valid articles.
#  ✔ Successfully processed and saved: Latin American socio-political dynamics.json
# Processing Communication in Education and Healthcare.json...
#  Kept 4960 / 5000 valid articles.
#  ✔ Successfully processed and saved: Communication in Education and Healthcare.json
# Processing Religious Education and Schools.json...
#  Kept 4976 / 4999 valid articles.
#  ✔ Successfully processed and saved: Religious Education and Schools.json
# Processing Political Systems and Governance.json...
#  Kept 4983 / 5000 valid articles.
#  ✔ Successfully processed and saved: Political Systems and Governance.json
# Processing Cultural, Media, and Literary Studies.json...
#  Kept 4946 / 5000 valid articles.
#  ✔ Successfully processed and saved: Cultural, Media, and Literary Studies.json
# Processing Maritime and Coastal Archaeology.json...
#  Kept 4995 / 5000 valid articles.
#  ✔ Successfully processed and saved: Maritime and Coastal Archaeology.json
# Processing Island Studies and Pacific Affairs.json...
#  Kept 4977 / 4998 valid articles.
#  ✔ Successfully processed and saved: Island Studies and Pacific Affairs.json
# Processing Scarabaeidae Beetle Taxonomy and Biogeography.json...
#  Kept 190 / 196 valid articles.
#  ✔ Successfully processed and saved: Scarabaeidae Beetle Taxonomy and Biogeography.json
# Processing Visual Culture and Art Theory.json...
#  Kept 4961 / 5000 valid articles.
#  ✔ Successfully processed and saved: Visual Culture and Art Theory.json
# Processing Legal case studies and regulations.json...
#  Kept 4964 / 4999 valid articles.
#  ✔ Successfully processed and saved: Legal case studies and regulations.json
# Processing Regional Development and Innovation.json...
#  Kept 4966 / 4988 valid articles.
#  ✔ Successfully processed and saved: Regional Development and Innovation.json
# Processing Halal products and consumer behavior.json...
#  Kept 4978 / 4999 valid articles.
#  ✔ Successfully processed and saved: Halal products and consumer behavior.json
# Processing Historical and socio-economic studies of Spain and related regions.json...
#  Kept 4973 / 5000 valid articles.
#  ✔ Successfully processed and saved: Historical and socio-economic studies of Spain and related regions.json
# Processing European history and politics.json...
#  Kept 4928 / 5000 valid articles.
#  ✔ Successfully processed and saved: European history and politics.json
# Processing Climate Change, Adaptation, Migration.json...
#  Kept 4990 / 5000 valid articles.
#  ✔ Successfully processed and saved: Climate Change, Adaptation, Migration.json
# Processing Language and Culture.json...
#  Kept 4954 / 4998 valid articles.
#  ✔ Successfully processed and saved: Language and Culture.json
# Processing Digitalization and Economic Development in Agriculture.json...
#  Kept 4975 / 4998 valid articles.
#  ✔ Successfully processed and saved: Digitalization and Economic Development in Agriculture.json
# Processing Historical Psychiatry and Medical Practices.json...
#  Kept 4934 / 4999 valid articles.
#  ✔ Successfully processed and saved: Historical Psychiatry and Medical Practices.json
# Processing Economic and Technological Developments in Russia.json...
#  Kept 4965 / 4998 valid articles.
#  ✔ Successfully processed and saved: Economic and Technological Developments in Russia.json
# Processing Comparative International Legal Studies.json...
#  Kept 4970 / 5000 valid articles.
#  ✔ Successfully processed and saved: Comparative International Legal Studies.json
# Processing Management and Marketing Education.json...
#  Kept 4973 / 4998 valid articles.
#  ✔ Successfully processed and saved: Management and Marketing Education.json
# Processing Urbanism, Landscape, and Tourism Studies.json...
#  Kept 4985 / 4997 valid articles.
#  ✔ Successfully processed and saved: Urbanism, Landscape, and Tourism Studies.json
# Processing Financial Reporting and Valuation Research.json...
#  Kept 4989 / 4995 valid articles.
#  ✔ Successfully processed and saved: Financial Reporting and Valuation Research.json
# Processing Themes in Literature Analysis.json...
#  Kept 4991 / 4998 valid articles.
#  ✔ Successfully processed and saved: Themes in Literature Analysis.json
# Processing Cultural and Mythological Studies.json...
#  Kept 4976 / 4999 valid articles.
#  ✔ Successfully processed and saved: Cultural and Mythological Studies.json
# Processing Focus Groups and Qualitative Methods.json...
#  Kept 4996 / 4998 valid articles.
#  ✔ Successfully processed and saved: Focus Groups and Qualitative Methods.json
# Processing Stuttering Research and Treatment.json...
#  Kept 4978 / 4999 valid articles.
#  ✔ Successfully processed and saved: Stuttering Research and Treatment.json
# Processing Cross-Border Cooperation and Integration.json...
#  Kept 4981 / 5000 valid articles.
#  ✔ Successfully processed and saved: Cross-Border Cooperation and Integration.json
# Processing Migration, Ethnicity, and Economy.json...
#  Kept 4979 / 5000 valid articles.
#  ✔ Successfully processed and saved: Migration, Ethnicity, and Economy.json
# Processing Central European national history.json...
#  Kept 4946 / 4999 valid articles.
#  ✔ Successfully processed and saved: Central European national history.json
# Processing Public Administration in Developing Nations.json...
#  Kept 4968 / 5000 valid articles.
#  ✔ Successfully processed and saved: Public Administration in Developing Nations.json
# Processing Categorization, perception, and language.json...
#  Kept 4990 / 4999 valid articles.
#  ✔ Successfully processed and saved: Categorization, perception, and language.json
# Processing Stress and Burnout Research.json...
#  Kept 4982 / 4999 valid articles.
#  ✔ Successfully processed and saved: Stress and Burnout Research.json
# Processing Hannah Arendt's Political Philosophy.json...
#  Kept 1935 / 1968 valid articles.
#  ✔ Successfully processed and saved: Hannah Arendt's Political Philosophy.json
# Processing Immigration and Intercultural Education.json...
#  Kept 4997 / 5000 valid articles.
#  ✔ Successfully processed and saved: Immigration and Intercultural Education.json
# Processing Economic and Financial Impacts of Cancer.json...
#  Kept 4962 / 5000 valid articles.
#  ✔ Successfully processed and saved: Economic and Financial Impacts of Cancer.json
# Processing Multimedia Communication and Technology.json...
#  Kept 4965 / 4977 valid articles.
#  ✔ Successfully processed and saved: Multimedia Communication and Technology.json
# Processing Youth Education and Societal Dynamics.json...
#  Kept 4976 / 4999 valid articles.
#  ✔ Successfully processed and saved: Youth Education and Societal Dynamics.json
# Processing Innovation Policy and R&D.json...
#  Kept 4982 / 4997 valid articles.
#  ✔ Successfully processed and saved: Innovation Policy and R&D.json
# Processing transportation and logistics systems.json...
#  Kept 4959 / 4981 valid articles.
#  ✔ Successfully processed and saved: transportation and logistics systems.json
# Processing Philosophical and Cultural Analysis.json...
#  Kept 4958 / 5000 valid articles.
#  ✔ Successfully processed and saved: Philosophical and Cultural Analysis.json
# Processing Weber, Simmel, Sociological Theory.json...
#  Kept 4958 / 5000 valid articles.
#  ✔ Successfully processed and saved: Weber, Simmel, Sociological Theory.json
# Processing Corporate Identity and Reputation.json...
#  Kept 4993 / 4998 valid articles.
#  ✔ Successfully processed and saved: Corporate Identity and Reputation.json
# Processing Spanish Culture and Identity.json...
#  Kept 4974 / 4998 valid articles.
#  ✔ Successfully processed and saved: Spanish Culture and Identity.json
# Processing Leadership and Management in Organizations.json...
#  Kept 4983 / 5000 valid articles.
#  ✔ Successfully processed and saved: Leadership and Management in Organizations.json
# Processing Information Systems and Technology Applications.json...
#  Kept 4979 / 4988 valid articles.
#  ✔ Successfully processed and saved: Information Systems and Technology Applications.json
# Processing Historical Studies on Spain.json...
#  Kept 4971 / 5000 valid articles.
#  ✔ Successfully processed and saved: Historical Studies on Spain.json
# Processing Global Peace and Security Dynamics.json...
#  Kept 4963 / 5000 valid articles.
#  ✔ Successfully processed and saved: Global Peace and Security Dynamics.json
# Processing Psychology, Coaching, and Therapy.json...
#  Kept 4978 / 4999 valid articles.
#  ✔ Successfully processed and saved: Psychology, Coaching, and Therapy.json
# Processing Legal Education and Practice Innovations.json...
#  Kept 4974 / 4999 valid articles.
#  ✔ Successfully processed and saved: Legal Education and Practice Innovations.json
# Processing Diverse Academia and Research Topics.json...
#  Kept 4973 / 5000 valid articles.
#  ✔ Successfully processed and saved: Diverse Academia and Research Topics.json
# Processing Polish Historical and Cultural Studies.json...
#  Kept 4981 / 5000 valid articles.
#  ✔ Successfully processed and saved: Polish Historical and Cultural Studies.json
# Processing Conflict of Laws and Jurisdiction.json...
#  Kept 4791 / 4999 valid articles.
#  ✔ Successfully processed and saved: Conflict of Laws and Jurisdiction.json
# Processing Linguistics and language evolution.json...
#  Kept 4974 / 4999 valid articles.
#  ✔ Successfully processed and saved: Linguistics and language evolution.json
# Processing Race, History, and American Society.json...
#  Kept 4955 / 4999 valid articles.
#  ✔ Successfully processed and saved: Race, History, and American Society.json
# Processing Philosophy, History, and Historiography.json...
#  Kept 4960 / 4999 valid articles.
#  ✔ Successfully processed and saved: Philosophy, History, and Historiography.json
# Processing Legal Issues in South Africa.json...
#  Kept 4974 / 5000 valid articles.
#  ✔ Successfully processed and saved: Legal Issues in South Africa.json
# Processing History of Medicine and Tropical Health.json...
#  Kept 4950 / 4999 valid articles.
#  ✔ Successfully processed and saved: History of Medicine and Tropical Health.json
# Processing Public Procurement and Policy.json...
#  Kept 4962 / 5000 valid articles.
#  ✔ Successfully processed and saved: Public Procurement and Policy.json
# Processing Migration, Aging, and Tourism Studies.json...
#  Kept 4990 / 4999 valid articles.
#  ✔ Successfully processed and saved: Migration, Aging, and Tourism Studies.json
# Processing Hong Kong and Taiwan Politics.json...
#  Kept 4987 / 4999 valid articles.
#  ✔ Successfully processed and saved: Hong Kong and Taiwan Politics.json
# Processing Innovation and Socioeconomic Development.json...
#  Kept 4972 / 4999 valid articles.
#  ✔ Successfully processed and saved: Innovation and Socioeconomic Development.json
# Processing Religious Tourism and Spaces.json...
#  Kept 4984 / 5000 valid articles.
#  ✔ Successfully processed and saved: Religious Tourism and Spaces.json
# Processing Human Behavior and Motivation.json...
#  Kept 4983 / 5000 valid articles.
#  ✔ Successfully processed and saved: Human Behavior and Motivation.json
# Processing Competency Development and Evaluation.json...
#  Kept 4976 / 4998 valid articles.
#  ✔ Successfully processed and saved: Competency Development and Evaluation.json
# Processing Cinema History and Criticism.json...
#  Kept 4966 / 5000 valid articles.
#  ✔ Successfully processed and saved: Cinema History and Criticism.json
# Processing Consumer Behavior and Market Dynamics.json...
#  Kept 4978 / 4999 valid articles.
#  ✔ Successfully processed and saved: Consumer Behavior and Market Dynamics.json
# Processing Ocean Acidification Effects and Responses.json...
#  Kept 4990 / 4999 valid articles.
#  ✔ Successfully processed and saved: Ocean Acidification Effects and Responses.json
# Processing Management and Organizational Practices.json...
#  Kept 4981 / 4999 valid articles.
#  ✔ Successfully processed and saved: Management and Organizational Practices.json
# Processing Geological Formations and Processes Exploration.json...
#  Kept 4989 / 4999 valid articles.
#  ✔ Successfully processed and saved: Geological Formations and Processes Exploration.json
# Processing Global Public Health Policies and Epidemiology.json...
#  Kept 4941 / 4998 valid articles.
#  ✔ Successfully processed and saved: Global Public Health Policies and Epidemiology.json
# Processing Defense, Military, and Policy Studies.json...
#  Kept 4969 / 5000 valid articles.
#  ✔ Successfully processed and saved: Defense, Military, and Policy Studies.json
# Processing Education Methods and Technologies.json...
#  Kept 4957 / 4975 valid articles.
#  ✔ Successfully processed and saved: Education Methods and Technologies.json
# Processing Emile Durkheim and Sociology.json...
#  Kept 4976 / 5000 valid articles.
#  ✔ Successfully processed and saved: Emile Durkheim and Sociology.json
# Processing Human Resource and Talent Management.json...
#  Kept 4969 / 4989 valid articles.
#  ✔ Successfully processed and saved: Human Resource and Talent Management.json
# Processing Psychology and Mental Health.json...
#  Kept 4954 / 4995 valid articles.
#  ✔ Successfully processed and saved: Psychology and Mental Health.json
# Processing Psychological Testing and Assessment.json...
#  Kept 4970 / 4994 valid articles.
#  ✔ Successfully processed and saved: Psychological Testing and Assessment.json
# Processing Firm Innovation and Growth.json...
#  Kept 4985 / 4997 valid articles.
#  ✔ Successfully processed and saved: Firm Innovation and Growth.json
# Processing Medieval Philosophy and Theology.json...
#  Kept 4959 / 5000 valid articles.
#  ✔ Successfully processed and saved: Medieval Philosophy and Theology.json
# Processing Historical Geography and Geographical Thought.json...
#  Kept 4970 / 4999 valid articles.
#  ✔ Successfully processed and saved: Historical Geography and Geographical Thought.json
# Processing Migration, Education, Indigenous Social Dynamics.json...
#  Kept 4956 / 4998 valid articles.
#  ✔ Successfully processed and saved: Migration, Education, Indigenous Social Dynamics.json
# Processing Catholicism and Religious Studies.json...
#  Kept 4977 / 5000 valid articles.
#  ✔ Successfully processed and saved: Catholicism and Religious Studies.json
# Processing Psychoanalysis and Social Critique.json...
#  Kept 4985 / 5000 valid articles.
#  ✔ Successfully processed and saved: Psychoanalysis and Social Critique.json
# Processing Photography and Visual Culture.json...
#  Kept 4965 / 5000 valid articles.
#  ✔ Successfully processed and saved: Photography and Visual Culture.json
# Processing Philippine History and Culture.json...
#  Kept 4978 / 5000 valid articles.
#  ✔ Successfully processed and saved: Philippine History and Culture.json
# Processing Social Issues in Poland.json...
#  Kept 4981 / 5000 valid articles.
#  ✔ Successfully processed and saved: Social Issues in Poland.json
# Processing Jungian Analytical Psychology.json...
#  Kept 4749 / 4998 valid articles.
#  ✔ Successfully processed and saved: Jungian Analytical Psychology.json
# Processing linguistics and terminology studies.json...
#  Kept 4964 / 5000 valid articles.
#  ✔ Successfully processed and saved: linguistics and terminology studies.json
# Processing Educational Assessment and Pedagogy.json...
#  Kept 4983 / 4999 valid articles.
#  ✔ Successfully processed and saved: Educational Assessment and Pedagogy.json
# Processing Qualitative Research Methods and Applications.json...
#  Kept 4993 / 5000 valid articles.
#  ✔ Successfully processed and saved: Qualitative Research Methods and Applications.json
# Processing Historical and Cultural Studies of Poland.json...
#  Kept 4982 / 5000 valid articles.
#  ✔ Successfully processed and saved: Historical and Cultural Studies of Poland.json
# Processing Digital Innovation in Industries.json...
#  Kept 4978 / 4994 valid articles.
#  ✔ Successfully processed and saved: Digital Innovation in Industries.json
# Processing Educational Strategies and Epistemologies.json...
#  Kept 4993 / 5000 valid articles.
#  ✔ Successfully processed and saved: Educational Strategies and Epistemologies.json
# Processing Psychoanalysis, Philosophy, and Politics.json...
#  Kept 4968 / 5000 valid articles.
#  ✔ Successfully processed and saved: Psychoanalysis, Philosophy, and Politics.json
# Processing Eurasian Exchange Networks.json...
#  Kept 4985 / 4999 valid articles.
#  ✔ Successfully processed and saved: Eurasian Exchange Networks.json
# Processing Social Power and Status Dynamics.json...
#  Kept 4966 / 4999 valid articles.
#  ✔ Successfully processed and saved: Social Power and Status Dynamics.json
# Processing Environmental law and policy.json...
#  Kept 4959 / 4998 valid articles.
#  ✔ Successfully processed and saved: Environmental law and policy.json
# Processing Public Policy and Governance.json...
#  Kept 4981 / 5000 valid articles.
#  ✔ Successfully processed and saved: Public Policy and Governance.json
# Processing Globalization and Cultural Identity.json...
#  Kept 4978 / 5000 valid articles.
#  ✔ Successfully processed and saved: Globalization and Cultural Identity.json
# Processing Shakespeare, Adaptation, and Literary Criticism.json...
#  Kept 4880 / 5000 valid articles.
#  ✔ Successfully processed and saved: Shakespeare, Adaptation, and Literary Criticism.json
# Processing Multidisciplinary Research Papers Compilation.json...
#  Kept 2161 / 2303 valid articles.
#  ✔ Successfully processed and saved: Multidisciplinary Research Papers Compilation.json
# Processing French Historical and Cultural Studies.json...
#  Kept 4969 / 5000 valid articles.
#  ✔ Successfully processed and saved: French Historical and Cultural Studies.json
# Processing Management Systems and Quality Improvement.json...
#  Kept 4974 / 4997 valid articles.
#  ✔ Successfully processed and saved: Management Systems and Quality Improvement.json
# Processing Healthcare Systems and Technology.json...
#  Kept 4965 / 4979 valid articles.
#  ✔ Successfully processed and saved: Healthcare Systems and Technology.json
# Processing Educational and Social Studies.json...
#  Kept 4983 / 4995 valid articles.
#  ✔ Successfully processed and saved: Educational and Social Studies.json
# Processing Memory, History, Trauma, Identity.json...
#  Kept 4982 / 4999 valid articles.
#  ✔ Successfully processed and saved: Memory, History, Trauma, Identity.json
# Processing Education and Cultural Studies.json...
#  Kept 4989 / 5000 valid articles.
#  ✔ Successfully processed and saved: Education and Cultural Studies.json
# Processing Franchising Strategies and Performance.json...
#  Kept 4995 / 4999 valid articles.
#  ✔ Successfully processed and saved: Franchising Strategies and Performance.json
# Processing Polish Law and Legal System.json...
#  Kept 4985 / 4999 valid articles.
#  ✔ Successfully processed and saved: Polish Law and Legal System.json
# Processing Educational Methods and Outcomes.json...
#  Kept 4984 / 4999 valid articles.
#  ✔ Successfully processed and saved: Educational Methods and Outcomes.json
# Processing Cultural Studies and Postmodernism.json...
#  Kept 4970 / 5000 valid articles.
#  ✔ Successfully processed and saved: Cultural Studies and Postmodernism.json
# Processing Quality Function Deployment in Product Design.json...
#  Kept 4985 / 4999 valid articles.
#  ✔ Successfully processed and saved: Quality Function Deployment in Product Design.json
# Processing Inclusion and Disability in Education and Sport.json...
#  Kept 4993 / 5000 valid articles.
#  ✔ Successfully processed and saved: Inclusion and Disability in Education and Sport.json
# Processing South Asian Studies and Diaspora.json...
#  Kept 4980 / 5000 valid articles.
#  ✔ Successfully processed and saved: South Asian Studies and Diaspora.json
# Processing Educational Environments and Student Outcomes.json...
#  Kept 4986 / 4998 valid articles.
#  ✔ Successfully processed and saved: Educational Environments and Student Outcomes.json
# Processing Critical Realism in Sociology.json...
#  Kept 4986 / 5000 valid articles.
#  ✔ Successfully processed and saved: Critical Realism in Sociology.json
# Processing School Leadership and Teacher Performance.json...
#  Kept 4954 / 4998 valid articles.
#  ✔ Successfully processed and saved: School Leadership and Teacher Performance.json
# Processing Law and Political Science.json...
#  Kept 4954 / 4999 valid articles.
#  ✔ Successfully processed and saved: Law and Political Science.json
# Processing War, Ethics, and Justification.json...
#  Kept 4983 / 5000 valid articles.
#  ✔ Successfully processed and saved: War, Ethics, and Justification.json
# Processing Digital Economy and Transformation.json...
#  Kept 4946 / 4988 valid articles.
#  ✔ Successfully processed and saved: Digital Economy and Transformation.json
# Processing Regional Development and Policy.json...
#  Kept 4971 / 5000 valid articles.
#  ✔ Successfully processed and saved: Regional Development and Policy.json
# Processing Russian Literature and Bakhtin Studies.json...
#  Kept 4927 / 5000 valid articles.
#  ✔ Successfully processed and saved: Russian Literature and Bakhtin Studies.json
# Processing Economic and Social Development.json...
#  Kept 4947 / 4998 valid articles.
#  ✔ Successfully processed and saved: Economic and Social Development.json
# Processing Names, Identity, and Discrimination Research.json...
#  Kept 4986 / 5000 valid articles.
#  ✔ Successfully processed and saved: Names, Identity, and Discrimination Research.json
# Processing German Colonialism and Identity Studies.json...
#  Kept 4969 / 5000 valid articles.
#  ✔ Successfully processed and saved: German Colonialism and Identity Studies.json
# Processing Modernist Literature and Criticism.json...
#  Kept 4975 / 5000 valid articles.
#  ✔ Successfully processed and saved: Modernist Literature and Criticism.json
# Processing Spanish Literature and Culture Studies.json...
#  Kept 4970 / 4999 valid articles.
#  ✔ Successfully processed and saved: Spanish Literature and Culture Studies.json
# Processing Family Caregiving in Mental Illness.json...
#  Kept 4991 / 5000 valid articles.
#  ✔ Successfully processed and saved: Family Caregiving in Mental Illness.json
# Processing Innovative Teaching Methodologies in Social Sciences.json...
#  Kept 4982 / 5000 valid articles.
#  ✔ Successfully processed and saved: Innovative Teaching Methodologies in Social Sciences.json
# Processing Maritime Security and History.json...
#  Kept 4978 / 5000 valid articles.
#  ✔ Successfully processed and saved: Maritime Security and History.json
# Processing Religion and Society in Latin America.json...
#  Kept 4963 / 5000 valid articles.
#  ✔ Successfully processed and saved: Religion and Society in Latin America.json
# Processing Legal principles and applications.json...
#  Kept 4911 / 4998 valid articles.
#  ✔ Successfully processed and saved: Legal principles and applications.json
# Processing Sociology and Education in Brazil.json...
#  Kept 4979 / 5000 valid articles.
#  ✔ Successfully processed and saved: Sociology and Education in Brazil.json
# Processing Conservation Techniques and Studies.json...
#  Kept 4992 / 4998 valid articles.
#  ✔ Successfully processed and saved: Conservation Techniques and Studies.json
# Processing Medical History and Innovations.json...
#  Kept 4953 / 5000 valid articles.
# ...
#  Kept 4980 / 4998 valid articles.
#  ✔ Successfully processed and saved: Digital Platforms and Economics.json
# Processing Cultural Differences and Values.json...
#  Kept 4991 / 4999 valid articles.
#  ✔ Successfully processed and saved: Cultural Differences and Values.json
# Processing Local Government Finance and Decentralization.json...
#  Kept 4992 / 5000 valid articles.
#  ✔ Successfully processed and saved: Local Government Finance and Decentralization.json
# Processing Museums and Cultural Heritage.json...
#  Kept 4969 / 4996 valid articles.
#  ✔ Successfully processed and saved: Museums and Cultural Heritage.json
# Processing Classical Philosophy and Thought.json...
#  Kept 4959 / 4999 valid articles.
#  ✔ Successfully processed and saved: Classical Philosophy and Thought.json
# Processing Sport and Mega-Event Impacts.json...
#  Kept 4989 / 4999 valid articles.
#  ✔ Successfully processed and saved: Sport and Mega-Event Impacts.json
# Processing Innovative Education and Learning Practices.json...
#  Kept 4974 / 4992 valid articles.
#  ✔ Successfully processed and saved: Innovative Education and Learning Practices.json
# Processing French Urban and Social Studies.json...
#  Kept 4971 / 5000 valid articles.
#  ✔ Successfully processed and saved: French Urban and Social Studies.json
# Processing Epistemology, Ethics, and Metaphysics.json...
#  Kept 4957 / 4999 valid articles.
#  ✔ Successfully processed and saved: Epistemology, Ethics, and Metaphysics.json
# Processing Tropical and Extratropical Cyclones Research.json...
#  Kept 4994 / 5000 valid articles.
#  ✔ Successfully processed and saved: Tropical and Extratropical Cyclones Research.json
# Processing Climate Change Communication and Perception.json...
#  Kept 4992 / 5000 valid articles.
#  ✔ Successfully processed and saved: Climate Change Communication and Perception.json
# Processing Credit Risk and Financial Regulations.json...
#  Kept 4977 / 4999 valid articles.
#  ✔ Successfully processed and saved: Credit Risk and Financial Regulations.json
# Processing Facility Location and Emergency Management.json...
#  Kept 4967 / 4999 valid articles.
#  ✔ Successfully processed and saved: Facility Location and Emergency Management.json
# Processing Children's Rights and Participation.json...
#  Kept 4973 / 5000 valid articles.
#  ✔ Successfully processed and saved: Children's Rights and Participation.json
# Processing Corporate Taxation and Avoidance.json...
#  Kept 4960 / 4997 valid articles.
#  ✔ Successfully processed and saved: Corporate Taxation and Avoidance.json
# Processing Religion and Society Interactions.json...
#  Kept 4968 / 4999 valid articles.
#  ✔ Successfully processed and saved: Religion and Society Interactions.json
# Processing Disability Education and Employment.json...
#  Kept 4964 / 5000 valid articles.
#  ✔ Successfully processed and saved: Disability Education and Employment.json
# Processing Visual and Cognitive Learning Processes.json...
#  Kept 4985 / 5000 valid articles.
#  ✔ Successfully processed and saved: Visual and Cognitive Learning Processes.json
# Processing Digital Mental Health Interventions.json...
#  Kept 4969 / 4997 valid articles.
#  ✔ Successfully processed and saved: Digital Mental Health Interventions.json
# Processing Innovative Teaching Methods.json...
#  Kept 4941 / 4976 valid articles.
#  ✔ Successfully processed and saved: Innovative Teaching Methods.json
# Processing Consumer Retail Behavior Studies.json...
#  Kept 4994 / 4999 valid articles.
#  ✔ Successfully processed and saved: Consumer Retail Behavior Studies.json
# Processing Healthcare Systems and Reforms.json...
#  Kept 4957 / 4999 valid articles.
#  ✔ Successfully processed and saved: Healthcare Systems and Reforms.json
# Processing Survey Methodology and Nonresponse.json...
#  Kept 4987 / 4998 valid articles.
#  ✔ Successfully processed and saved: Survey Methodology and Nonresponse.json
# Processing Neuroendocrine regulation and behavior.json...
#  Kept 4996 / 5000 valid articles.
#  ✔ Successfully processed and saved: Neuroendocrine regulation and behavior.json
# Processing Employee Performance and Motivation.json...
#  Kept 4985 / 5000 valid articles.
#  ✔ Successfully processed and saved: Employee Performance and Motivation.json
# Processing Global trade, sustainability, and social impact.json...
#  Kept 4978 / 5000 valid articles.
#  ✔ Successfully processed and saved: Global trade, sustainability, and social impact.json
# Processing Poverty, Education, and Child Welfare.json...
#  Kept 4977 / 5000 valid articles.
#  ✔ Successfully processed and saved: Poverty, Education, and Child Welfare.json
# Processing Indian and Buddhist Studies.json...
#  Kept 4979 / 5000 valid articles.
#  ✔ Successfully processed and saved: Indian and Buddhist Studies.json
# Processing Information Technology Governance and Strategy.json...
#  Kept 4982 / 4998 valid articles.
#  ✔ Successfully processed and saved: Information Technology Governance and Strategy.json
# Processing Risk Perception and Management.json...
#  Kept 4968 / 4998 valid articles.
#  ✔ Successfully processed and saved: Risk Perception and Management.json
# Processing Cognitive Abilities and Testing.json...
#  Kept 4993 / 4997 valid articles.
#  ✔ Successfully processed and saved: Cognitive Abilities and Testing.json
# Processing Second Language Acquisition and Learning.json...
#  Kept 4979 / 4997 valid articles.
#  ✔ Successfully processed and saved: Second Language Acquisition and Learning.json
# Processing Phenomenology and Existential Philosophy.json...
#  Kept 4975 / 4999 valid articles.
#  ✔ Successfully processed and saved: Phenomenology and Existential Philosophy.json
# Processing Tree-ring climate responses.json...
#  Kept 4993 / 4999 valid articles.
#  ✔ Successfully processed and saved: Tree-ring climate responses.json
# Processing Fiscal Policies and Political Economy.json...
#  Kept 4955 / 5000 valid articles.
#  ✔ Successfully processed and saved: Fiscal Policies and Political Economy.json
# Processing Retirement, Disability, and Employment.json...
#  Kept 4978 / 5000 valid articles.
#  ✔ Successfully processed and saved: Retirement, Disability, and Employment.json
# Processing Linguistic Variation and Morphology.json...
#  Kept 4990 / 5000 valid articles.
#  ✔ Successfully processed and saved: Linguistic Variation and Morphology.json
# Processing Family and Disability Support Research.json...
#  Kept 4955 / 5000 valid articles.
#  ✔ Successfully processed and saved: Family and Disability Support Research.json
# Processing Building materials and conservation.json...
#  Kept 4976 / 4998 valid articles.
#  ✔ Successfully processed and saved: Building materials and conservation.json
# Processing Urban, Neighborhood, and Segregation Studies.json...
#  Kept 4994 / 5000 valid articles.
#  ✔ Successfully processed and saved: Urban, Neighborhood, and Segregation Studies.json
# Processing Diaspora, migration, transnational identity.json...
#  Kept 4984 / 5000 valid articles.
#  ✔ Successfully processed and saved: Diaspora, migration, transnational identity.json
# Processing Financial Distress and Bankruptcy Prediction.json...
#  Kept 4992 / 4998 valid articles.
#  ✔ Successfully processed and saved: Financial Distress and Bankruptcy Prediction.json
# Processing Digital and Traditional Archives Management.json...
#  Kept 4992 / 4999 valid articles.
#  ✔ Successfully processed and saved: Digital and Traditional Archives Management.json
# Processing Parental Involvement in Education.json...
#  Kept 4973 / 5000 valid articles.
#  ✔ Successfully processed and saved: Parental Involvement in Education.json
# Processing Sports Analytics and Performance.json...
#  Kept 4989 / 4996 valid articles.
#  ✔ Successfully processed and saved: Sports Analytics and Performance.json
# Processing South African History and Culture.json...
#  Kept 4964 / 5000 valid articles.
#  ✔ Successfully processed and saved: South African History and Culture.json
# Processing Healthcare Decision-Making and Restraints.json...
#  Kept 4977 / 4998 valid articles.
#  ✔ Successfully processed and saved: Healthcare Decision-Making and Restraints.json
# Processing Underwater Acoustics Research.json...
#  Kept 4930 / 5000 valid articles.
#  ✔ Successfully processed and saved: Underwater Acoustics Research.json
# Processing Conflict Management and Negotiation.json...
#  Kept 4990 / 5000 valid articles.
#  ✔ Successfully processed and saved: Conflict Management and Negotiation.json
# Processing Intergenerational Family Dynamics and Caregiving.json...
#  Kept 1278 / 1298 valid articles.
#  ✔ Successfully processed and saved: Intergenerational Family Dynamics and Caregiving.json
# Processing COVID-19 Pandemic Impacts.json...
#  Kept 4989 / 4999 valid articles.
#  ✔ Successfully processed and saved: COVID-19 Pandemic Impacts.json
# Processing Education and Critical Thinking Development.json...
#  Kept 4975 / 4995 valid articles.
#  ✔ Successfully processed and saved: Education and Critical Thinking Development.json
# Processing Postcolonial and Cultural Literary Studies.json...
#  Kept 4972 / 5000 valid articles.
#  ✔ Successfully processed and saved: Postcolonial and Cultural Literary Studies.json
# Processing Organizational Management and Innovation.json...
#  Kept 4976 / 4998 valid articles.
#  ✔ Successfully processed and saved: Organizational Management and Innovation.json
# Processing Geochemistry and Elemental Analysis.json...
#  Kept 4991 / 4999 valid articles.
#  ✔ Successfully processed and saved: Geochemistry and Elemental Analysis.json
# Processing Product Development and Customization.json...
#  Kept 4973 / 4998 valid articles.
#  ✔ Successfully processed and saved: Product Development and Customization.json
# Processing Decision Support System Applications.json...
#  Kept 4972 / 4995 valid articles.
#  ✔ Successfully processed and saved: Decision Support System Applications.json
# Processing Economic Theory and Policy.json...
#  Kept 4965 / 5000 valid articles.
#  ✔ Successfully processed and saved: Economic Theory and Policy.json
# Processing Political Economy and Marxism.json...
#  Kept 4959 / 5000 valid articles.
#  ✔ Successfully processed and saved: Political Economy and Marxism.json
# Processing Transboundary Water Resource Management.json...
#  Kept 4989 / 5000 valid articles.
#  ✔ Successfully processed and saved: Transboundary Water Resource Management.json
# Processing Mentoring and Academic Development.json...
#  Kept 4982 / 4998 valid articles.
#  ✔ Successfully processed and saved: Mentoring and Academic Development.json
# Processing Seismic Waves and Analysis.json...
#  Kept 4996 / 5000 valid articles.
#  ✔ Successfully processed and saved: Seismic Waves and Analysis.json
# Processing Law, Economics, and Judicial Systems.json...
#  Kept 4975 / 5000 valid articles.
#  ✔ Successfully processed and saved: Law, Economics, and Judicial Systems.json
# Processing Resilience and Mental Health.json...
#  Kept 4984 / 4997 valid articles.
#  ✔ Successfully processed and saved: Resilience and Mental Health.json
# Processing Music Therapy and Health.json...
#  Kept 4965 / 4990 valid articles.
#  ✔ Successfully processed and saved: Music Therapy and Health.json
# Processing Copyright and Intellectual Property.json...
#  Kept 4948 / 4998 valid articles.
#  ✔ Successfully processed and saved: Copyright and Intellectual Property.json
# Processing Fiscal Policy and Economic Growth.json...
#  Kept 4924 / 5000 valid articles.
#  ✔ Successfully processed and saved: Fiscal Policy and Economic Growth.json
# Processing Irish and British Studies.json...
#  Kept 4964 / 5000 valid articles.
#  ✔ Successfully processed and saved: Irish and British Studies.json
# Processing Recreation, Leisure, Wilderness Management.json...
#  Kept 3095 / 3272 valid articles.
#  ✔ Successfully processed and saved: Recreation, Leisure, Wilderness Management.json
# Processing Higher Education and Employability.json...
#  Kept 4974 / 4998 valid articles.
#  ✔ Successfully processed and saved: Higher Education and Employability.json
# Processing Turkey's Politics and Society.json...
#  Kept 4967 / 4999 valid articles.
#  ✔ Successfully processed and saved: Turkey's Politics and Society.json
# Processing Pharmaceutical Economics and Policy.json...
#  Kept 4980 / 4999 valid articles.
#  ✔ Successfully processed and saved: Pharmaceutical Economics and Policy.json
# Processing Early Modern Spanish Literature.json...
#  Kept 4968 / 4998 valid articles.
#  ✔ Successfully processed and saved: Early Modern Spanish Literature.json
# Processing Humor Studies and Applications.json...
#  Kept 4978 / 4999 valid articles.
#  ✔ Successfully processed and saved: Humor Studies and Applications.json
# Processing Service-Learning and Community Engagement.json...
#  Kept 4981 / 5000 valid articles.
#  ✔ Successfully processed and saved: Service-Learning and Community Engagement.json
# Processing Housing, Finance, and Neoliberalism.json...
#  Kept 4992 / 5000 valid articles.
#  ✔ Successfully processed and saved: Housing, Finance, and Neoliberalism.json
# Processing Learning Styles and Cognitive Differences.json...
#  Kept 4984 / 4998 valid articles.
#  ✔ Successfully processed and saved: Learning Styles and Cognitive Differences.json
# Processing Sustainability in Higher Education.json...
#  Kept 4957 / 4999 valid articles.
#  ✔ Successfully processed and saved: Sustainability in Higher Education.json
# Processing Natural Resources and Economic Development.json...
#  Kept 4958 / 4994 valid articles.
#  ✔ Successfully processed and saved: Natural Resources and Economic Development.json
# Processing Family Business Performance and Succession.json...
#  Kept 4989 / 5000 valid articles.
#  ✔ Successfully processed and saved: Family Business Performance and Succession.json
# Processing Cultural Heritage Management and Preservation.json...
#  Kept 4979 / 5000 valid articles.
#  ✔ Successfully processed and saved: Cultural Heritage Management and Preservation.json
# Processing Intellectual Capital and Performance Analysis.json...
#  Kept 4985 / 5000 valid articles.
#  ✔ Successfully processed and saved: Intellectual Capital and Performance Analysis.json
# Processing Urban Development and Societal Issues.json...
#  Kept 4988 / 5000 valid articles.
#  ✔ Successfully processed and saved: Urban Development and Societal Issues.json
# Processing Educator Training and Historical Pedagogy.json...
#  Kept 4990 / 5000 valid articles.
#  ✔ Successfully processed and saved: Educator Training and Historical Pedagogy.json
# Processing Supply Chain Resilience and Risk Management.json...
#  Kept 4983 / 4997 valid articles.
#  ✔ Successfully processed and saved: Supply Chain Resilience and Risk Management.json
# Processing Legal Studies and Policies.json...
#  Kept 4975 / 4999 valid articles.
#  ✔ Successfully processed and saved: Legal Studies and Policies.json
# Processing German Literature and Culture Studies.json...
#  Kept 4946 / 4997 valid articles.
#  ✔ Successfully processed and saved: German Literature and Culture Studies.json
# Processing Social and Cultural Dynamics.json...
#  Kept 4970 / 4999 valid articles.
#  ✔ Successfully processed and saved: Social and Cultural Dynamics.json
# Processing Private Equity and Venture Capital.json...
#  Kept 4991 / 5000 valid articles.
#  ✔ Successfully processed and saved: Private Equity and Venture Capital.json
# Processing Economics of Agriculture and Food Markets.json...
#  Kept 4977 / 4999 valid articles.
#  ✔ Successfully processed and saved: Economics of Agriculture and Food Markets.json
# Processing Subterranean biodiversity and taxonomy.json...
#  Kept 2639 / 2686 valid articles.
#  ✔ Successfully processed and saved: Subterranean biodiversity and taxonomy.json
# Processing Spatial and Panel Data Analysis.json...
#  Kept 4987 / 4996 valid articles.
#  ✔ Successfully processed and saved: Spatial and Panel Data Analysis.json
# Processing Outsourcing and Supply Chain Management.json...
#  Kept 4994 / 5000 valid articles.
#  ✔ Successfully processed and saved: Outsourcing and Supply Chain Management.json
# Processing Literacy, Media, and Education.json...
#  Kept 4934 / 4998 valid articles.
#  ✔ Successfully processed and saved: Literacy, Media, and Education.json
# Processing ERP Systems Implementation and Impact.json...
#  Kept 4991 / 4996 valid articles.
#  ✔ Successfully processed and saved: ERP Systems Implementation and Impact.json
# 🎉 All files processed and saved to the new folder!
